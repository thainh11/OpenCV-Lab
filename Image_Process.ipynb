# %%
import cv2 
img = cv2.imread('lenna.jpg')
cv2.imshow('original',img)
cv2.waitKey(0)
# Out:
# -1

# %%
img_ = img.copy()

#img.shape trả về kích thước của ảnh 512x512
print(img.shape)
# Out:
# (512, 512, 3)

# %%
for row in range(img_.shape[0]):
    for col in range(img_.shape[1]):
        #print(img_[row,col])
        img_[row,col] = img_[row,col] + 5
# cộng 5 đơn vị vào mỗi phần tử của ảnh
print(img[30,20])
print(img_[30,20])
# Out:
# [110 135 227]
# [115 140 232]

# %%
print(img[:,:,0].max())
# Out:
# 230

# %%
from PIL import Image
import numpy as np
img= Image.open('D:\CPV301\Code CPV\lenna.jpg')
img= np.array(img)
import numpy as np
B = img[:,:,0].max()
G = img[:,:,1].max()
R = img[:,:,2].max()
cb = np.array([[255/B,0,0],
              [0,255/G,0],
               [0,0,255/R],
              
              ])
img_array = np.array(img)
for row in range(img_.shape[0]):
    for col in range(img_.shape[1]):
        #print(img_[row,col])
        img_[row,col] = np.dot(cb,img_array[row,col].T)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(img_)
plt.show()

# %%
# calcHist(image, channels, mask, histSize, ranges[, hist[, accumulate]])
histr= cv2.calcHist([img],[0],None,[256],[0,256])
# histr_1= cv2.calcHist([img],[1],None,[256],[0,256])
# histr_2= cv2.calcHist([img],[2],None,[256],[0,256])
plt.plot(histr,c='b')
# plt.plot(histr_1,c='g')
# plt.plot(histr_2,c='r')

# %%
import matplotlib.pyplot as plt
plt.imshow(img_)
plt.show()

# %%
import numpy as np
def compute_hist(img):
    hist = np.zeros((256,), np.uint8)
    h, w = img.shape[:2]
    for i in range(h):
        for j in range(w):
            hist[img[i][j]] += 1
    return hist
def equal_hist(hist):
    cumulator = np.zeros_like(hist, np.float64)
    for i in range(len(cumulator)):
        cumulator[i] = hist[:i].sum()
    #print(cumulator)
    new_hist = (cumulator - cumulator.min())/(cumulator.max() - cumulator.min()) * 255
    #new_hist = np.uint8(new_hist)
    return new_hist

# %%
import cv2 
img = cv2.imread('D:\CPV301\Code CPV\lenna.jpg')
#cv2.imshow('original',img)
#cv2.waitKey(0)
hist = compute_hist(img[:,:,0])
new_hist = equal_hist(hist)

h, w = img.shape[:2]
for i in range(h):
    for j in range(w):
        img[i,j,0] = new_hist[img[i,j,0]]
       
fig = plt.figure()
ax = plt.subplot(121)
img[:,:,1]=0
img[:,:,2]=0
plt.imshow(img[:,:,0])

plt.subplot(122)
plt.plot(new_hist)
plt.show()

# %%
histr = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr,c='blue',label='Blue')

# %%
#original
import cv2 
img = cv2.imread('D:\CPV301\Code CPV\lenna.jpg')
fig = plt.figure()
ax = plt.subplot(121)
img[:,:,1]=0
img[:,:,2]=0
plt.imshow(img[:,:,0])

plt.subplot(122)
plt.plot(new_hist)
plt.show()

# %%
histr = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr,c='blue',label='Blue')
histr
# Out:
# array([[0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+01],
#        [1.000e+01],
#        [1.000e+01],
#        [1.400e+01],
#        [2.300e+01],
#        [2.500e+01],
# ...

# %%
import cv2
image = cv2.imread("D:\CPV301\Code CPV\lenna.jpg")
img_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# convert the YUV image back to RGB format
img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
cv2.imshow('img_input',image)
cv2.imshow('img_output',img_output)
cv2.waitKey(0)
# Out:
# -1
